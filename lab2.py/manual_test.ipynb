# %%
from circle import Circle 
from rectangle import Rectangle

# %%
c1 = Circle (0, 0, 1)
c2 = Circle ( 2, 2, 5)
print(c1.area)
print(c1.perimeter)
# Out:
# 3.141592653589793
# 6.283185307179586

# %%
print(f"{c2.area:.2f}")
print(c2.perimeter)
# Out:
# 78.54
# 31.41592653589793

# %%
try:
    Circle(radius=True)
except TypeError as err:
    print(err)
# Out:
#  The radius cannot be boolien

# %%
c1
c2
# Out:
# Circle(x = 2, y = 2 , radius=5)

# %%
try: 
    Circle(radius="2")
except TypeError as err:
    print(err)
# Out:
# You must type numbers

# %%
try:
    Circle(radius=-2)
except ValueError as err:
    print(err )
# Out:
# Radius must be posotive

# %%
Circle(-5, 0, radius=2)
# Out:
# Circle(x = -5, y = 0 , radius=2)

# %%
c1
# Out:
# Circle(x = 0, y = 0 , radius=1)

# %%
c1 >= c2 # I got false 
c1 == c2 # I got false
c1 <= c2 # true 
c1 < c2  # true 
c1 > c2  # false
# Out:
# False

# %%
rec1 = Rectangle(5, 6, 3, 3) # instanciate my rectangle. 
rec2 = Rectangle (7, 8, 8, 4)# nr :2 
rec1
# Out:
# Rectangle (x = 5, y = 6,width = 3, height = 3)

# %%
c1 >= rec1 # I gott true thefour i activate the c.o that goes to the area of diferent shapes and compare them. 
c1 <= rec1 # I gott fals becous the area is not less or equale to the rectangel area.
# Out:
# True

# %%
c1.translate( 5 ,3 )
c1
# Out:
# Circle(x = 5, y = 3 , radius=1)

# %%
try:
    c1.translate(True,5)
except TypeError as err:
    print(err)
# Out:
#  ---- The value cannot be a boolean ----

# %%
try:
    c1.translate("five", 3)
except TypeError as err:
    print (err )
# Out:
#  ---- The value must be a number ----

# %%
try:
    rec2 = Rectangle(width = 3 , heigth = "5") 
except TypeError as err:
    print(err)
# Out:
# Rectangle.__init__() got an unexpected keyword argument 'heigth'

# %%
try:
    rec2 = Rectangle(width = -6 , height = 7 )
except ValueError as err:
    print(err)
# Out:
#  ---- The width and the heigth must be positive ----

# %%
c1
# Out:
# Circle(x = 5, y = 3 , radius=1)

# %%
c1.translate(-5,-3)

# %%
print(c1.unit_circle())   # jobba pè unitet test eftersom den funkar inte
# Out:
# True

# %%
c1
# Out:
# Circle(x = 0, y = 0 , radius=1)

# %%
rec1.area, c1.area
# Out:
# (9, 3.141592653589793)

# %%
rec1 == c1
# Out:
# False

# %%
rec1 < c1
# Out:
# False

# %%
c1.radius = 1 
print(c1.radius)
# Out:
# 1

# %%
try:
   Circle(radius= True)
except TypeError as err:
   print(err)
# Out:
#  The radius cannot be boolien

# %%
try:
    rec_2 = Rectangle(width= 2, height = "7")
except TypeError as err:
    print(err)
# Out:
#  ---- You must type a number ----

# %%
rec1 >= rec2 #  false 
rec1 == rec2 #  false 
rec1 <= rec2 #  true 
rec1 < rec2  #  true 
rec1 > rec2  #  false
# Out:
# False
