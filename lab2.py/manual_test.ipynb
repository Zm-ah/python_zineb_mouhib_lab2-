# %%
from circle import Circle 
from rectangle import Rectangle

# %%
c1 = Circle (0, 0, 2)
c2 = Circle ( 2, 2, 5)
print(c1.area)
print(c1.perimeter)
# Out:
# 12.566370614359172
# 12.566370614359172

# %%
Circle(radius=True)
# Out:
# Circle(center= (0,0), radius = True , area = 3.141593, perimeter = 6.283185)

# %%
# Circle(x=0,y=0,radius=2)
c1, c2
# Out:
# (Circle(center= (0,0), radius = 2 , area = 12.566371, perimeter = 12.566371),
#  Circle(center= (2,2), radius = 5 , area = 78.539816, perimeter = 31.415927))

# %%
try: 
    Circle(radius="2")
except TypeError as err:
    print(err)
# Out:
# You must type numbers

# %%
try:
    Circle(radius=-2)
except ValueError as err:
    print(err )
# Out:
# Radius must be posotive

# %%
Circle(-5,0,radius=2)
# Out:
# Circle(center= (-5,0), radius = 2 , area = 12.566371, perimeter = 12.566371)

# %%
c1, c2
# Out:
# (Circle(center= (0,0), radius = 2 , area = 12.566371, perimeter = 12.566371),
#  Circle(center= (2,2), radius = 4 , area = 50.265482, perimeter = 25.132741))

# %%
c1 >= c2
# Out:
# False

# %%
rec1  = Rectangle(5, 6, 3, 3) 
rec2 = Rectangle (7,8,8,4)
rec1 , rec2
# Out:
# (rectangle (width =3,heigth = 3, area =9.000000., perimeter= 12.000000)),
#  rectangle (width =8,heigth = 4, area =32.000000., perimeter= 24.000000)))
