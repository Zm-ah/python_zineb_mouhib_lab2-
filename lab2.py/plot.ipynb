# %%
from circle import Circle 
from rectangle import Rectangle
c1 = Circle(0 ,0, 1)
c2 = Circle(2 ,2, 5)
rec1 = Rectangle(5, 6, 3, 3)

# %%
import matplotlib as plt 
from matplotlib import patches


fig, ax = plt.subplot(1)

circle_patch1 = patches.Circle ((c1.x, c1.y), radius = c1.radius , fill = False)
circle_patch2 = patches.Circle ((c2.x, c2.y), radius = c2.radius, fill = False )
ax.add_patch(circle_patch1)
ax.add_patch(circle_patch2)
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.grid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       1 import matplotlib as plt
#       2 from matplotlib import patches
# ----> 5 fig, ax = plt.subplot(1)
#       7 circle_patch1 = patches.Circle ((c1.x, c1.y), radius = c1.radius , fill = False)
#       8 circle_patch2 = patches.Circle ((c2.x, c2.y), radius = c2.radius, fill = False )
#
# File ~/Documents/python_zineb_mouhib_lab2-/.venv/lib/python3.12/site-packages/matplotlib/_api/__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'subplot'
