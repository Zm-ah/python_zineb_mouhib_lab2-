# %% [markdown]
# # The first circle

# %%
from circle import Circle 
import matplotlib.pyplot as plt
import numpy as np

radie=1
vinklar = np.linspace(0,np.pi*4,400)
xl = np.sin(vinklar)*radie
yl = np.cos(vinklar)*radie

plt.figure(figsize=(4,4))
plt.grid()
plt.plot(xl,yl)
