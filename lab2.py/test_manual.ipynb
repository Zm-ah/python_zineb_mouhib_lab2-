# %%
from shape import Shape
from circle import Circle 
import math 


c1 = (0,0,4)
print(c1.area)
print(c1.perimeter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 7
#       3 import math
#       6 c1 = (0,0,4)
# ----> 7 print(c1.area)
#       8 print(c1.perimeter)
#
# AttributeError: 'tuple' object has no attribute 'area'
