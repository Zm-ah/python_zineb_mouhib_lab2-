# %%
from circle import Circle 

c1 = Circle (0, 0, 4 )
print(c1)
print("area:" ,c1.area)
print("perimeter:", c1.perimeter)


c1.radius = 10 
print(c1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 from circle import Circle
# ----> 3 c1 = Circle (0, 0, 4 )
#       4 print(c1)
#       5 print("area:" ,c1.area)
#
# TypeError: Circle.__init__() takes from 1 to 2 positional arguments but 4 were given
