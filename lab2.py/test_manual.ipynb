# %%
from circle import Circle 
from rectangle import Rectangle

# %%
c1 = Circle (0, 0, 2)
c2 = Circle ( 2, 2, 4)
print(c1.area)
print(c1.perimeter)
# Out:
# 12.566370614359172
# 12.566370614359172

# %%
# Circle(x=0, y=0, radius=2)
c1
# Out:
# Circle(radius=2),center= (0,0)

# %%
# annan typeerror
try:
    Circle(radius="2")
except TypeError as err:
    print(err)
# Out:
# '<=' not supported between instances of 'str' and 'int'

# %%
Circle(radius=-2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 Circle(radius=-2)
#
# File ~/Documents/python_zineb_mouhib_lab2-/lab2.py/circle.py:9, in Circle.__init__(self, x, y, radius)
#       7 super().__init__(x, y)
#       8 if radius <= 0:
# ----> 9     raise ValueError("Radius must be posotive")
#      10 self._radius = radius
#
# ValueError: Radius must be posotive

# %%
Circle(-5,0,radius=2)
# Out:
# Circle(radius=2),center= (-5,0)

# %%
c1, c2
# Out:
# (Circle(radius=2),center= (0,0), Circle(radius=4),center= (2,2))

# %%
c1 >= c2
# Out:
# False

# %%
rec = Rectangle(5, 6, 3, 3)
