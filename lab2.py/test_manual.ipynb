# %%
from shape import Shape
from circle import Circle 
import math 


c1 = Circle(4)
print(c1.area)
print(c1.perimeter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       2 from circle import Circle
#       3 import math
# ----> 6 c1 = Circle(4)
#       7 print(c1.area)
#       8 print(c1.perimeter)
#
# File ~/Documents/python_zineb_mouhib_lab2-/lab2.py/circle.py:5, in __init__(self, radius)
#       4 def __init__(self, x = 0, y = 0 ,radius = 3):
# ----> 5     super().__init__(x, y)
#       6     if radius <= 0:
#       7         raise ValueError("Radius must be posotive")
#
# NameError: name 'x' is not defined
